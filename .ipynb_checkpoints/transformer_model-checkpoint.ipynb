# %%
import pandas as pd

# %%
cleaned_matches_stacked = pd.read_csv('./Data/cleaned_matches_stacked.csv')
cleaned_matches_stacked.head()
# Out:
#                          game_id        date  \
# 0     2016-01-03IndiaAfghanistan  2016-01-03
# 1     2016-01-03IndiaAfghanistan  2016-01-03
# 2        2016-01-06EstoniaSweden  2016-01-06
# 3        2016-01-06EstoniaSweden  2016-01-06
# 4  2016-01-08BangladeshSri Lanka  2016-01-08
#
#                                location         team          opp  score  \
# 0     South Asian Championship in India        India  Afghanistan      2
# 1     South Asian Championship in India  Afghanistan        India      1
# 2  Friendly in the United Arab Emirates      Estonia       Sweden      1
# 3  Friendly in the United Arab Emirates       Sweden      Estonia      1
# 4    Bangabandhu Gold Cup in Bangladesh   Bangladesh    Sri Lanka      4
#
#    opp_score   elo  opp_elo  elo_diff result_class
# 0          1  1063     1143       -80           T1
# 1          2  1143     1063        80           T2
# 2          1  1494     1767      -273            D
# 3          1  1767     1494       273            D
# 4          2   890      775       115           T1

# %%
print(cleaned_matches_stacked['date'].min())
print(cleaned_matches_stacked['date'].max())
# Out:
# 2016-01-03
# 2025-01-22

# %%
def num_outcome(row):
    if row['result_class'] == 'T1':
        val = 1
    elif row['result_class'] == 'D':
        val = 0
    elif row['result_class'] == 'T2':
        val = -1
    else:
        raise Exception
    return val

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import classification_report
import optuna

# Configuration
SEED = 42
NUM_EPOCHS = 10
BATCH_SIZE = 32
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Set random seeds
np.random.seed(SEED)
torch.manual_seed(SEED)
if DEVICE.type == 'cuda':
    torch.cuda.manual_seed_all(SEED)

# Import data
# game_id,date,location,team,opp,score,opp_score,elo,opp_elo,elo_diff,result_class
data = pd.read_csv('./Data/cleaned_matches_stacked.csv')

# Convert result to numeric
data['outcome'] = data.apply(num_outcome, axis=1) + 1
# data['outcome'] = data['result_class']

# Preprocessing
le = LabelEncoder()
data['team'] = le.fit_transform(data['team'])
data['opp'] = le.transform(data['opp'])

# Split features and target
X = data[['team', 'opp', 'elo', 'opp_elo', 'elo_diff']] #'score', 'opp_score', 
y = data['outcome']

n = len(data[data['date'] < '2024-01-01'])

# Split data on time
X_train, X_val, y_train, y_val = X[:n], X[n:], y[:n], y[n:]

# Dataset class
class SportsDataset(Dataset):
    def __init__(self, features, labels):
        self.features = features
        self.labels = labels
        
    def __len__(self):
        return len(self.features)
    
    def __getitem__(self, idx):
        return {
            'team': torch.tensor(self.features.iloc[idx]['team'], dtype=torch.long),
            'opp': torch.tensor(self.features.iloc[idx]['opp'], dtype=torch.long),
            'numerical': torch.tensor(self.features.iloc[idx][['elo', 'opp_elo', 'elo_diff']], dtype=torch.float),
            'labels': torch.tensor(self.labels.iloc[idx], dtype=torch.long)
        }

# Create dataloaders
train_dataset = SportsDataset(X_train, y_train)
val_dataset = SportsDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE)

# Transformer model
class SportsTransformer(nn.Module):
    def __init__(self, num_teams, numerical_features, embedding_dim=64, 
                 num_heads=4, num_layers=3, dropout=0.1):
        super().__init__()
        self.team_embedding = nn.Embedding(num_teams, embedding_dim)
        self.numerical_projection = nn.Linear(numerical_features, embedding_dim)
        
        self.transformer = nn.TransformerEncoder(
            nn.TransformerEncoderLayer(
                d_model=embedding_dim,
                nhead=num_heads,
                dim_feedforward=embedding_dim*4,
                dropout=dropout,
                batch_first=True
            ),
            num_layers=num_layers
        )
        self.classifier = nn.Linear(embedding_dim, 3)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, team, opp, numerical):
        # Embed categorical features
        team1_emb = self.team_embedding(team)
        team2_emb = self.team_embedding(opp)
        
        # Project numerical features
        num_emb = self.numerical_projection(numerical)
        
        # Combine features
        combined = torch.stack([team1_emb, team2_emb, num_emb], dim=1)
        
        # Transformer processing
        transformer_out = self.transformer(combined)
        
        # Classification
        pooled = torch.mean(transformer_out, dim=1)
        return self.classifier(self.dropout(pooled))

# Training function
def train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=10):
    model.to(DEVICE)
    best_val_loss = float('inf')
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        
        for batch in train_loader:
            optimizer.zero_grad()
            
            inputs = {k: v.to(DEVICE) for k, v in batch.items() if k != 'labels'}
            labels = batch['labels'].to(DEVICE)
            
            outputs = model(**inputs)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item() * labels.size(0)
        
        # Validation
        model.eval()
        val_loss = 0.0
        all_preds = []
        all_labels = []
        
        with torch.no_grad():
            for batch in val_loader:
                inputs = {k: v.to(DEVICE) for k, v in batch.items() if k != 'labels'}
                labels = batch['labels'].to(DEVICE)
                
                outputs = model(**inputs)
                loss = criterion(outputs, labels)
                
                val_loss += loss.item() * labels.size(0)
                all_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
                all_labels.extend(labels.cpu().numpy())
        
        # Calculate metrics
        train_loss = train_loss / len(train_loader.dataset)
        val_loss = val_loss / len(val_loader.dataset)
        val_acc = (np.array(all_preds) == np.array(all_labels)).mean()
        
        print(f'Epoch {epoch+1}/{num_epochs}')
        print(f'Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Acc: {val_acc:.4f}')
        
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), 'best_model.pth')
    
    return model

# Hyperparameter optimization with Optuna
def objective(trial):
    params = {
        'embedding_dim': trial.suggest_categorical('embedding_dim', [32, 64, 128]),
        'num_heads': trial.suggest_categorical('num_heads', [2, 4, 8]),
        'num_layers': trial.suggest_int('num_layers', 1, 4),
        'learning_rate': trial.suggest_float('learning_rate', 1e-5, 1e-3, log=True),
        'dropout': trial.suggest_float('dropout', 0.1, 0.5)
    }
    
    model = SportsTransformer(
        num_teams=len(le.classes_),
        numerical_features=3,
        embedding_dim=params['embedding_dim'],
        num_heads=params['num_heads'],
        num_layers=params['num_layers'],
        dropout=params['dropout']
    )
    
    optimizer = optim.AdamW(model.parameters(), lr=params['learning_rate'])
    criterion = nn.CrossEntropyLoss()
    
    # Reduced number of epochs for faster tuning
    model = train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=5)
    
    # Evaluate final validation loss
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for batch in val_loader:
            inputs = {k: v.to(DEVICE) for k, v in batch.items() if k != 'labels'}
            labels = batch['labels'].to(DEVICE)
            outputs = model(**inputs)
            val_loss += criterion(outputs, labels).item()
    
    return val_loss / len(val_loader)

# %%
# Run optimization
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10)

# Train final model with best parameters
best_params = study.best_params
print("Best hyperparameters:", best_params)
# Out:
# [I 2025-01-30 20:44:53,319] A new study created in memory with name: no-name-c8e6f826-3c6d-46ff-801d-c7c99479043b
# 128 2
# Epoch 1/5
# Train Loss: 0.9678 | Val Loss: 0.9567 | Val Acc: 0.5737
# Epoch 2/5
# Train Loss: 0.9298 | Val Loss: 0.9325 | Val Acc: 0.5741
# Epoch 3/5
# Train Loss: 0.9210 | Val Loss: 0.9405 | Val Acc: 0.5618
# Epoch 4/5
# Train Loss: 0.9220 | Val Loss: 0.9255 | Val Acc: 0.5710
# Epoch 5/5
# Train Loss: 0.9214 | Val Loss: 0.9334 | Val Acc: 0.5737
# [I 2025-01-30 20:46:24,448] Trial 0 finished with value: 0.9336494251533791 and parameters: {'embedding_dim': 128, 'num_heads': 2, 'num_layers': 3, 'learning_rate': 0.00033543769671098654, 'dropout': 0.4060572381738937}. Best is trial 0 with value: 0.9336494251533791.
# 32 2
# Epoch 1/5
# Train Loss: 1.1564 | Val Loss: 1.0786 | Val Acc: 0.4386
# Epoch 2/5
# Train Loss: 1.1205 | Val Loss: 1.0623 | Val Acc: 0.4745
# Epoch 3/5
# Train Loss: 1.1032 | Val Loss: 1.0405 | Val Acc: 0.5108
# Epoch 4/5
# Train Loss: 1.0900 | Val Loss: 1.0303 | Val Acc: 0.5116
# Epoch 5/5
# Train Loss: 1.0759 | Val Loss: 0.9970 | Val Acc: 0.5405
# [I 2025-01-30 20:47:28,752] Trial 1 finished with value: 0.9970590604676141 and parameters: {'embedding_dim': 32, 'num_heads': 2, 'num_layers': 4, 'learning_rate': 6.192996841582757e-05, 'dropout': 0.48997625620746743}. Best is trial 0 with value: 0.9336494251533791.
# 32 8
# Epoch 1/5
# Train Loss: 0.9750 | Val Loss: 0.9352 | Val Acc: 0.5726
# Epoch 2/5
# Train Loss: 0.9327 | Val Loss: 0.9427 | Val Acc: 0.5683
# Epoch 3/5
# Train Loss: 0.9293 | Val Loss: 0.9281 | Val Acc: 0.5730
# Epoch 4/5
# Train Loss: 0.9262 | Val Loss: 0.9319 | Val Acc: 0.5680
# Epoch 5/5
# Train Loss: 0.9289 | Val Loss: 0.9260 | Val Acc: 0.5718
# [I 2025-01-30 20:48:19,309] Trial 2 finished with value: 0.9262251802432684 and parameters: {'embedding_dim': 32, 'num_heads': 8, 'num_layers': 1, 'learning_rate': 0.000894214375660243, 'dropout': 0.41260287909073423}. Best is trial 2 with value: 0.9262251802432684.
# 32 8
# Epoch 1/5
# Train Loss: 0.9435 | Val Loss: 0.9280 | Val Acc: 0.5714
# Epoch 2/5
# Train Loss: 0.9178 | Val Loss: 0.9400 | Val Acc: 0.5645
# Epoch 3/5
# Train Loss: 0.9160 | Val Loss: 0.9372 | Val Acc: 0.5749
# Epoch 4/5
# Train Loss: 0.9141 | Val Loss: 0.9344 | Val Acc: 0.5672
# Epoch 5/5
# Train Loss: 0.9121 | Val Loss: 0.9287 | Val Acc: 0.5699
# [I 2025-01-30 20:49:08,989] Trial 3 finished with value: 0.9289618605448876 and parameters: {'embedding_dim': 32, 'num_heads': 8, 'num_layers': 1, 'learning_rate': 0.0006293191577605281, 'dropout': 0.13766472234335728}. Best is trial 2 with value: 0.9262251802432684.
# 32 8
# Epoch 1/5
# Train Loss: 0.9849 | Val Loss: 0.9228 | Val Acc: 0.5714
# Epoch 2/5
# Train Loss: 0.9286 | Val Loss: 0.9206 | Val Acc: 0.5710
# Epoch 3/5
# Train Loss: 0.9224 | Val Loss: 0.9206 | Val Acc: 0.5737
# Epoch 4/5
# Train Loss: 0.9176 | Val Loss: 0.9221 | Val Acc: 0.5691
# Epoch 5/5
# Train Loss: 0.9160 | Val Loss: 0.9206 | Val Acc: 0.5722
# [I 2025-01-30 20:50:09,908] Trial 4 finished with value: 0.9208621934608177 and parameters: {'embedding_dim': 32, 'num_heads': 8, 'num_layers': 3, 'learning_rate': 9.383680566877701e-05, 'dropout': 0.11895517932429854}. Best is trial 4 with value: 0.9208621934608177.
# 32 4
# Epoch 1/5
# Train Loss: 1.0543 | Val Loss: 0.9484 | Val Acc: 0.5726
# Epoch 2/5
# Train Loss: 0.9705 | Val Loss: 0.9546 | Val Acc: 0.5710
# Epoch 3/5
# Train Loss: 0.9532 | Val Loss: 0.9315 | Val Acc: 0.5730
# Epoch 4/5
# Train Loss: 0.9473 | Val Loss: 0.9498 | Val Acc: 0.5722
# Epoch 5/5
# Train Loss: 0.9401 | Val Loss: 0.9318 | Val Acc: 0.5718
# [I 2025-01-30 20:51:11,656] Trial 5 finished with value: 0.932104738774123 and parameters: {'embedding_dim': 32, 'num_heads': 4, 'num_layers': 4, 'learning_rate': 0.000439411558820778, 'dropout': 0.4976111821682929}. Best is trial 4 with value: 0.9208621934608177.
# 128 8
# Epoch 1/5
# Train Loss: 0.9380 | Val Loss: 0.9247 | Val Acc: 0.5672
# Epoch 2/5
# Train Loss: 0.9203 | Val Loss: 0.9254 | Val Acc: 0.5699
# Epoch 3/5
# Train Loss: 0.9177 | Val Loss: 0.9319 | Val Acc: 0.5734
# Epoch 4/5
# Train Loss: 0.9178 | Val Loss: 0.9224 | Val Acc: 0.5745
# Epoch 5/5
# Train Loss: 0.9176 | Val Loss: 0.9343 | Val Acc: 0.5568
# [I 2025-01-30 20:52:16,824] Trial 6 finished with value: 0.9344884267559758 and parameters: {'embedding_dim': 128, 'num_heads': 8, 'num_layers': 2, 'learning_rate': 0.0008253444275862166, 'dropout': 0.1751200971441175}. Best is trial 4 with value: 0.9208621934608177.
# 32 4
# Epoch 1/5
# Train Loss: 1.0345 | Val Loss: 0.9368 | Val Acc: 0.5707
# Epoch 2/5
# Train Loss: 0.9497 | Val Loss: 0.9346 | Val Acc: 0.5734
# Epoch 3/5
# Train Loss: 0.9369 | Val Loss: 0.9297 | Val Acc: 0.5710
# Epoch 4/5
# Train Loss: 0.9299 | Val Loss: 0.9378 | Val Acc: 0.5695
# Epoch 5/5
# Train Loss: 0.9303 | Val Loss: 0.9313 | Val Acc: 0.5726
# [I 2025-01-30 20:53:20,925] Trial 7 finished with value: 0.9315491642481015 and parameters: {'embedding_dim': 32, 'num_heads': 4, 'num_layers': 4, 'learning_rate': 0.00016528690055802277, 'dropout': 0.30811892395137774}. Best is trial 4 with value: 0.9208621934608177.
# 128 8
# Epoch 1/5
# Train Loss: 1.0979 | Val Loss: 0.9561 | Val Acc: 0.5691
# Epoch 2/5
# Train Loss: 1.0048 | Val Loss: 0.9549 | Val Acc: 0.5714
# Epoch 3/5
# Train Loss: 0.9734 | Val Loss: 0.9706 | Val Acc: 0.5734
# Epoch 4/5
# Train Loss: 0.9629 | Val Loss: 0.9681 | Val Acc: 0.5730
# Epoch 5/5
# Train Loss: 0.9559 | Val Loss: 0.9669 | Val Acc: 0.5714
# [I 2025-01-30 20:55:06,049] Trial 8 finished with value: 0.9672200330245642 and parameters: {'embedding_dim': 128, 'num_heads': 8, 'num_layers': 4, 'learning_rate': 1.610902430518331e-05, 'dropout': 0.4125768447976722}. Best is trial 4 with value: 0.9208621934608177.
# 64 8
# Epoch 1/5
# Train Loss: 0.9856 | Val Loss: 0.9303 | Val Acc: 0.5718
# Epoch 2/5
# Train Loss: 0.9374 | Val Loss: 0.9409 | Val Acc: 0.5730
# Epoch 3/5
# Train Loss: 0.9281 | Val Loss: 0.9261 | Val Acc: 0.5722
# Epoch 4/5
# Train Loss: 0.9267 | Val Loss: 0.9341 | Val Acc: 0.5722
# [W 2025-01-30 20:56:00,543] Trial 9 failed with parameters: {'embedding_dim': 64, 'num_heads': 8, 'num_layers': 3, 'learning_rate': 0.0001467387291337261, 'dropout': 0.3260100019130133} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/darts/lib/python3.8/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/var/folders/dz/tr83xlw16s72f8ct7200pjz40000gn/T/ipykernel_76919/2054008984.py", line 187, in objective
#     model = train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=5)
#   File "/var/folders/dz/tr83xlw16s72f8ct7200pjz40000gn/T/ipykernel_76919/2054008984.py", line 127, in train_model
#     optimizer.step()
#   File "/opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/optimizer.py", line 484, in wrapper
#     out = func(*args, **kwargs)
#   File "/opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/optimizer.py", line 89, in _use_grad
#     ret = func(self, *args, **kwargs)
#   File "/opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/adamw.py", line 227, in step
#     adamw(
#   File "/opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/optimizer.py", line 161, in maybe_fallback
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/adamw.py", line 767, in adamw
#     func(
#   File "/opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/adamw.py", line 434, in _single_tensor_adamw
#     param.addcdiv_(exp_avg, denom, value=-step_size)
# KeyboardInterrupt
# [W 2025-01-30 20:56:00,548] Trial 9 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 3
#       1 # Run optimization
#       2 study = optuna.create_study(direction='minimize')
# ----> 3 study.optimize(objective, n_trials=10)
#       5 # Train final model with best parameters
#       6 best_params = study.best_params
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/optuna/study/study.py:475, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     373 def optimize(
#     374     self,
#     375     func: ObjectiveFuncType,
#    (...)
#     382     show_progress_bar: bool = False,
#     383 ) -> None:
#     384     """Optimize an objective function.
#     385
#     386     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     473             If nested invocation of this method occurs.
#     474     """
# --> 475     _optimize(
#     476         study=self,
#     477         func=func,
#     478         n_trials=n_trials,
#     479         timeout=timeout,
#     480         n_jobs=n_jobs,
#     481         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     482         callbacks=callbacks,
#     483         gc_after_trial=gc_after_trial,
#     484         show_progress_bar=show_progress_bar,
#     485     )
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/optuna/study/_optimize.py:248, in _run_trial(study, func, catch)
#     241         assert False, "Should not reach."
#     243 if (
#     244     frozen_trial.state == TrialState.FAIL
#     245     and func_err is not None
#     246     and not isinstance(func_err, catch)
#     247 ):
# --> 248     raise func_err
#     249 return frozen_trial
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/optuna/study/_optimize.py:197, in _run_trial(study, func, catch)
#     195 with get_heartbeat_thread(trial._trial_id, study._storage):
#     196     try:
# --> 197         value_or_values = func(trial)
#     198     except exceptions.TrialPruned as e:
#     199         # TODO(mamu): Handle multi-objective cases.
#     200         state = TrialState.PRUNED
#
# Cell In[26], line 187, in objective(trial)
#     184 criterion = nn.CrossEntropyLoss()
#     186 # Reduced number of epochs for faster tuning
# --> 187 model = train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs=5)
#     189 # Evaluate final validation loss
#     190 model.eval()
#
# Cell In[26], line 127, in train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs)
#     124     loss = criterion(outputs, labels)
#     126     loss.backward()
# --> 127     optimizer.step()
#     129     train_loss += loss.item() * labels.size(0)
#     131 # Validation
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/optimizer.py:484, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     479         else:
#     480             raise RuntimeError(
#     481                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     482             )
# --> 484 out = func(*args, **kwargs)
#     485 self._optimizer_step_code()
#     487 # call optimizer step post hooks
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/optimizer.py:89, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      87     torch.set_grad_enabled(self.defaults["differentiable"])
#      88     torch._dynamo.graph_break()
# ---> 89     ret = func(self, *args, **kwargs)
#      90 finally:
#      91     torch._dynamo.graph_break()
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/adamw.py:227, in AdamW.step(self, closure)
#     214     beta1, beta2 = cast(Tuple[float, float], group["betas"])
#     216     has_complex = self._init_group(
#     217         group,
#     218         params_with_grad,
#    (...)
#     224         state_steps,
#     225     )
# --> 227     adamw(
#     228         params_with_grad,
#     229         grads,
#     230         exp_avgs,
#     231         exp_avg_sqs,
#     232         max_exp_avg_sqs,
#     233         state_steps,
#     234         amsgrad=amsgrad,
#     235         beta1=beta1,
#     236         beta2=beta2,
#     237         lr=group["lr"],
#     238         weight_decay=group["weight_decay"],
#     239         eps=group["eps"],
#     240         maximize=group["maximize"],
#     241         foreach=group["foreach"],
#     242         capturable=group["capturable"],
#     243         differentiable=group["differentiable"],
#     244         fused=group["fused"],
#     245         grad_scale=getattr(self, "grad_scale", None),
#     246         found_inf=getattr(self, "found_inf", None),
#     247         has_complex=has_complex,
#     248     )
#     250 return loss
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/optimizer.py:161, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     159     return disabled_func(*args, **kwargs)
#     160 else:
# --> 161     return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/adamw.py:767, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     764 else:
#     765     func = _single_tensor_adamw
# --> 767 func(
#     768     params,
#     769     grads,
#     770     exp_avgs,
#     771     exp_avg_sqs,
#     772     max_exp_avg_sqs,
#     773     state_steps,
#     774     amsgrad=amsgrad,
#     775     beta1=beta1,
#     776     beta2=beta2,
#     777     lr=lr,
#     778     weight_decay=weight_decay,
#     779     eps=eps,
#     780     maximize=maximize,
#     781     capturable=capturable,
#     782     differentiable=differentiable,
#     783     grad_scale=grad_scale,
#     784     found_inf=found_inf,
#     785     has_complex=has_complex,
#     786 )
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/optim/adamw.py:434, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     431     else:
#     432         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
# --> 434     param.addcdiv_(exp_avg, denom, value=-step_size)
#     436 # Lastly, switch back to complex view
#     437 if amsgrad and torch.is_complex(params[i]):
#
# KeyboardInterrupt:

# %%
final_model = SportsTransformer(
    num_teams=len(le.classes_),
    numerical_features=3,
    embedding_dim=best_params['embedding_dim'],
    num_heads=best_params['num_heads'],
    num_layers=best_params['num_layers'],
    dropout=best_params['dropout']
)

optimizer = optim.AdamW(final_model.parameters(), lr=best_params['learning_rate'])
criterion = nn.CrossEntropyLoss()

final_model = train_model(final_model, train_loader, val_loader, optimizer, criterion, num_epochs=NUM_EPOCHS)

# %%
final_model = SportsTransformer(
    num_teams=len(le.classes_),
    numerical_features=3,
    # embedding_dim=best_params['embedding_dim'],
    # num_heads=best_params['num_heads'],
    # num_layers=best_params['num_layers'],
    # dropout=best_params['dropout']
)

optimizer = optim.AdamW(final_model.parameters()) # , lr=best_params['learning_rate']
criterion = nn.CrossEntropyLoss()

final_model = train_model(final_model, train_loader, val_loader, optimizer, criterion, num_epochs=NUM_EPOCHS)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 13
#      10 optimizer = optim.AdamW(final_model.parameters()) # , lr=best_params['learning_rate']
#      11 criterion = nn.CrossEntropyLoss()
# ---> 13 final_model = train_model(final_model, train_loader, val_loader, optimizer, criterion, num_epochs=NUM_EPOCHS)
#
# Cell In[13], line 117, in train_model(model, train_loader, val_loader, optimizer, criterion, num_epochs)
#     114 model.train()
#     115 train_loss = 0.0
# --> 117 for batch in train_loader:
#     118     optimizer.zero_grad()
#     120     inputs = {k: v.to(DEVICE) for k, v in batch.items() if k != 'labels'}
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/utils/data/dataloader.py:673, in _SingleProcessDataLoaderIter._next_data(self)
#     671 def _next_data(self):
#     672     index = self._next_index()  # may raise StopIteration
# --> 673     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674     if self._pin_memory:
#     675         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# File /opt/anaconda3/envs/darts/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py:52, in <listcomp>(.0)
#      50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
# ---> 52         data = [self.dataset[idx] for idx in possibly_batched_index]
#      53 else:
#      54     data = self.dataset[possibly_batched_index]
#
# Cell In[13], line 60, in SportsDataset.__getitem__(self, idx)
#      55 def __getitem__(self, idx):
#      56     return {
#      57         'team': torch.tensor(self.features.iloc[idx]['team'], dtype=torch.long),
#      58         'opp': torch.tensor(self.features.iloc[idx]['opp'], dtype=torch.long),
#      59         'numerical': torch.tensor(self.features.iloc[idx][['elo', 'opp_elo', 'elo_diff']], dtype=torch.float),
# ---> 60         'labels': torch.tensor(self.labels.iloc[idx], dtype=torch.long)
#      61     }
#
# TypeError: new(): invalid data type 'str'

# %%
# Evaluation
def evaluate_model(model, dataloader):
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for batch in dataloader:
            inputs = {k: v.to(DEVICE) for k, v in batch.items() if k != 'labels'}
            labels = batch['labels'].cpu().numpy()
            
            outputs = model(**inputs)
            preds = torch.argmax(outputs, dim=1).cpu().numpy()
            
            all_preds.extend(preds)
            all_labels.extend(labels)
    
    print(classification_report(all_labels, all_preds))

print("Validation set evaluation:")
evaluate_model(final_model, val_loader)
